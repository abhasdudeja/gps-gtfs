# %%
import pandas as pd
import folium
# Out:
# The kernel failed to start as the Python Environment 'Python312\python.exe' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# Example: Generate synthetic noisy GPS data
np.random.seed(42)
num_samples = 1000
noise = np.random.normal(scale=0.01, size=(num_samples, 2))
clean_data = np.linspace(0, 1, num_samples).reshape(-1, 1)
noisy_data = clean_data + noise

# Create labels by adding more noise
clean_labels = clean_data + np.random.normal(scale=0.005, size=(num_samples, 2))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(noisy_data, clean_labels, test_size=0.2, random_state=42)

# Preprocess the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(2)  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_data=(X_test_scaled, y_test))

# Evaluate the model
loss = model.evaluate(X_test_scaled, y_test)
print("Mean Squared Error on Test Data:", loss)

# Example inference
sample_input = np.array([[0.6]])  # Replace with your own input data
sample_input_scaled = scaler.transform(sample_input)
predicted_output = model.predict(sample_input_scaled)
print("Predicted Output:", predicted_output)
# Out:
# WARNING:tensorflow:From e:\GitHub\gps-gtfs\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From e:\GitHub\gps-gtfs\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From e:\GitHub\gps-gtfs\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 25/25 [==============================] - 1s 9ms/step - loss: 0.1987 - val_loss: 0.0577
# Epoch 2/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0317 - val_loss: 0.0184
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0044
# Epoch 4/50
# ...
